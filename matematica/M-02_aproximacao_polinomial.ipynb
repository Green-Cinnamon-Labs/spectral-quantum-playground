# %% [markdown]
# # M-02 — Polynomial Approximation
#
# **Vínculo com o projeto:** Transformações polinomiais são o mecanismo central de QSP/QSVT — ver C-08.
# **Natureza:** exploração matemática — não é pré-requisito bloqueante por padrão
#
# ---
#
# Aproximação polinomial estuda como funções podem ser representadas ou aproximadas por polinômios. Para algoritmos quânticos, o interesse é em quais funções admitem aproximações polinomiais eficientes e com quais graus.
#
# *Esqueleto — desenvolver seções sobre: aproximação de Chebyshev, funções de sinal e step, grau vs. erro de aproximação, conexão com QSP.*
#
# ---
#
# ## Por que isso importa para algoritmos quânticos?
#
# *Preencher ao desenvolver o notebook.*
