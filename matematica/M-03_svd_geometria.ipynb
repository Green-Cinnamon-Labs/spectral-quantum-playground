# %% [markdown]
# # M-03 — SVD: Geometria e Interpretação
#
# **Vínculo com o projeto:** SVD é a estrutura que QSVT processa — ver C-07, C-08.
# **Natureza:** exploração matemática — não é pré-requisito bloqueante por padrão
#
# ---
#
# A decomposição em valores singulares (SVD) de qualquer matriz A decompõe a transformação linear em três etapas: rotação no domínio, escala, rotação no contradomínio. Os valores singulares são os fatores de escala.
#
# *Esqueleto — desenvolver seções sobre: geometria da SVD, relação com autovalores, pseudo-inversa, low-rank approximation, condição de uma matriz.*
#
# ---
#
# ## Por que isso importa para algoritmos quânticos?
#
# *Preencher ao desenvolver o notebook.*
